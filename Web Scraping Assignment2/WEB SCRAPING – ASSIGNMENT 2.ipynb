# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 2

# %% [markdown]
# Ans:-1

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r'C:\Users\Ravishankar\Documents\chromedriver.exe')

# %%
driver.get("https://www.naukri.com")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys("Data Analyst")

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Scraping Job Title
Job_Title=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    Job_Title.append(i.text)
    
Job_Title
# Out:
# ['Data Analyst - CRM Platform',
#  'Hiring For Data Analyst (DA)/ Team Lead (TL) -Clinical Data management',
#  'Payroll Transformation Data Analyst',
#  'Master Data Management Business Analyst',
#  'Data Analytics and Interpretation Business Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst | Fortune500 Retail Company']

# %%
#Scraping Location
Location=[]

location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    Location.append(i.text)
    
Location
# Out:
# ['Bangalore/Bengaluru, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Ahmedabad',
#  'Bangalore/Bengaluru, Kolkata, Hyderabad/Secunderabad, Pune, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
#Scraping Company Name
Company_Name=[]

company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    Company_Name.append(i.text)
    
Company_Name
# Out:
# ['Artech infosystem',
#  'Cognizant',
#  'Arrow Electronics',
#  'Accenture',
#  'Accenture',
#  'ANZ',
#  'ANZ',
#  'Goalreify Ventures',
#  'Goalreify Ventures',
#  'Talent500']

# %%
#Scrapin Experience
Exp_Req=[]

Experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in Experience_tags[0:10]:
    Exp_Req.append(i.text)
    
Exp_Req
# Out:
# ['1-6 Yrs',
#  '3-8 Yrs',
#  '5-10 Yrs',
#  '6-8 Yrs',
#  '6-8 Yrs',
#  '7-12 Yrs',
#  '7-12 Yrs',
#  '3-6 Yrs',
#  '4-6 Yrs',
#  '3-8 Yrs']

# %%
df=pd.DataFrame({'Job_Title':Job_Title,'Job_location':Location,'Company_Name':Company_Name,'Experience_Required':Exp_Req})
df
# Out:
#                                            Job_Title  \
# 0                        Data Analyst - CRM Platform
# 1  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 2                Payroll Transformation Data Analyst
# 3            Master Data Management Business Analyst
# 4  Data Analytics and Interpretation Business Ana...
# 5                                       Data Analyst
# 6                                       Data Analyst
# 7                                Senior Data Analyst
# 8                                Senior Data Analyst
# 9    Senior Data Analyst | Fortune500 Retail Company
#
#                                         Job_location        Company_Name  \
# 0  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...   Artech infosystem
# 1  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...           Cognizant
# 2                                Bangalore/Bengaluru   Arrow Electronics
# 3                                Bangalore/Bengaluru           Accenture
# ...

# %% [markdown]
# Ans:-2

# %%
driver.get('https://www.naukri.com')

# %%
designation=driver.find_element(By.CLASS_NAME,'suggestor-input')
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %%
#Scraping Job Title
Job_Title=[]

job_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in job_tags[0:10]:
    Job_Title.append(i.text)
    
Job_Title
# Out:
# ['Data Science Specialist',
#  'Data Science Manager',
#  'Mongodb Database Administrator, Maria DB or Cassandra',
#  'Analystics & Modeling Specialist',
#  'Assistant Manager - Data Science',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Module Lead - BIDW',
#  'Data Scientist: Artificial Intelligence',
#  'ACN - Applied Intelligence - C4DI - Sustainability - 09']

# %%
#scrapin Job location
Job_Location=[]

loc=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc[0:10]:
    Job_Location.append(i.text)
    
Job_Location
# Out:
# ['Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune, Chennai, Delhi / NCR, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, delhi ncr',
#  'Bangalore/Bengaluru, Mumbai, Pune',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Mumbai, New Delhi, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
#scraping Company Name

Company_Name=[]

Name=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in Name[0:10]:
    Company_Name.append(i.text)
    
Company_Name
# Out:
# ['Accenture',
#  'Accenture',
#  'Mphasis',
#  'Accenture',
#  'CitiusTech',
#  'Tech Mahindra',
#  'Boston Consulting Group',
#  'Mphasis',
#  'IBM',
#  'Accenture']

# %%
df=pd.DataFrame({'Job-Title':Job_Title,'Job-Location':Job_Location,'Company-Name':Company_Name})
df
# Out:
#                                            Job-Title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                              Senior Data Scientist
# 7                                 Module Lead - BIDW
# 8            Data Scientist: Artificial Intelligence
# 9  ACN - Applied Intelligence - C4DI - Sustainabi...
#
#                                         Job-Location             Company-Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...                  Mphasis
# ...

# %% [markdown]
# Ans:-3

# %%
driver.get('https://www.naukri.com')

# %%
designation=driver.find_element(By.CLASS_NAME,'suggestor-input')
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
#Applying Location(DElhi/NCR) filter
check=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[3]')
check.click()

# %%
#Applying Salary(3-6Lakhs) filter
check=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]')
check.click()

# %%
#scraping Job Title
Job_Title=[]
name=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in name[0:10]:
    Job_Title.append(i.text)
    
#Scraping Job location
Job_Location=[]
loc=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc[0:10]:
    Job_Location.append(i.text)
    
#Scraping Company Name
Company_Name=[]
cname=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in cname[0:10]:
    Company_Name.append(i.text)

# %%
df=pd.DataFrame({'Job-Title':Job_Title,'Job-Location':Job_Location,'Company-Name':Company_Name})
df
# Out:
#                                    Job-Title  \
# 0                             Data Scientist
# 1            DigitalBCG GAMMA Data Scientist
# 2                        Lead Data Scientist
# 3                             Data Scientist
# 4          Data Scientist - Engine Algorithm
# 5                             Data Scientist
# 6        Data Scientist / Chat-bot Developer
# 7  Data Activation Specialist - Adobe Target
# 8                             Data Scientist
# 9                             Data Scientist
#
#                                         Job-Location             Company-Name
# 0                 Noida, Nagpur, Bangalore/Bengaluru              GlobalLogic
# 1                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# 2         Noida(Sector-59 Noida)\n(WFH during Covid)  R Systems International
# 3                                   Gurgaon/Gurugram               IHS Markit
# ...

# %% [markdown]
# Ans:-4

# %%
driver.get('https://www.flipkart.com')

# %%
product=driver.find_element(By.CLASS_NAME,'_3704LK')
product.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
#Scraping Brand
Brand=[]
name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in name:
    Brand.append(i.text)
Brand
# Out:
# ['FOSSIL',
#  'FOSSIL',
#  'Fastrack',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'SHAAH COLLECTIONS',
#  'NuVew',
#  'FOSSIL',
#  'Bedst',
#  'SHAAH COLLECTIONS',
#  'MODE',
#  'FOSSIL',
#  'SHAAH COLLECTIONS',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'OAKLEY',
#  'NuVew',
#  'Fastrack',
#  'NuVew',
#  'OAKLEY',
#  'PIRASO',
#  'Fastrack',
#  'Fastrack',
#  'OAKLEY',
#  'Mi',
#  'Fastrack',
#  'Fastrack',
#  'OAKLEY',
#  'SUNBEE',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'OAKLEY',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'PIRASO',
#  'OAKLEY',
#  'Fastrack',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Singco India']

# %%
#scraping Product Description
Product_Des=[]
pd=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in pd:
    Product_Des.append(i.text)
Product_Des
# Out:
# ['Others Rectangular Sunglasses (54)',
#  'Others Aviator Sunglasses (58)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (57)',
#  'Others Aviator Sunglasses (61)',
#  'Others Round Sunglasses (59)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'Others Round Sunglasses (50)',
#  'UV Protection, Mirrored Wayfarer Sunglasses (54)',
#  'UV Protection, Mirrored Wayfarer Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'Rectangular Sunglass',
#  'UV Protection, Mirrored Wayfarer Sunglasses (57)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Wayfarer Sunglasses (57)',
#  'Shield Sunglass',
#  'UV Protection Aviator Sunglasses (54)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
# ...

# %%
#scraping price
Price=[]
price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹2,279',
#  '₹2,899',
#  '₹499',
#  '₹79',
#  '₹449',
#  '₹79',
#  '₹100',
#  '₹2,909',
#  '₹79',
#  '₹79',
#  '₹79',
#  '₹2,199',
#  '₹79',
#  '₹79',
#  '₹499',
#  '₹7,799',
#  '₹74',
#  '₹809',
#  '₹79',
#  '₹6,449',
#  '₹167',
#  '₹375',
#  '₹459',
#  '₹10,929',
#  '₹499',
#  '₹479',
#  '₹529',
#  '₹6,889',
#  '₹214',
#  '₹79',
#  '₹359',
#  '₹5,139',
#  '₹184',
#  '₹79',
#  '₹244',
#  '₹5,979',
#  '₹459',
#  '₹461',
#  '₹424',
#  '₹507']

# %%
Brand_name=[]

# %%
#scraping Brand from next page
start=1
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        Brand_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
Brand_name
# Out:
# ['FOSSIL',
#  'FOSSIL',
#  'Fastrack',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'SHAAH COLLECTIONS',
#  'NuVew',
#  'FOSSIL',
#  'Bedst',
#  'SHAAH COLLECTIONS',
#  'MODE',
#  'FOSSIL',
#  'SHAAH COLLECTIONS',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'OAKLEY',
#  'NuVew',
#  'Fastrack',
#  'NuVew',
#  'OAKLEY',
#  'PIRASO',
#  'Fastrack',
#  'Fastrack',
#  'OAKLEY',
#  'Mi',
#  'Fastrack',
#  'Fastrack',
#  'OAKLEY',
#  'SUNBEE',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'OAKLEY',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'PIRASO',
#  'OAKLEY',
#  'Fastrack',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Singco India',
#  'IDEE',
#  'New Specs',
#  'Fastrack',
#  'FOSSIL',
#  'Sewell',
#  'LIZA ANGEL',
#  'VINCENT CHASE',
#  'ROZZETTA CRAFT',
#  'SHAAH COLLECTIONS',
#  'VINCENT CHASE',
#  'Fastrack',
#  'VINCENT CHASE',
#  'DEIXELS',
#  'Fastrack',
#  'New Specs',
#  'CARRERA',
#  'shah collections',
#  'Fastrack',
#  'VINCENT CHASE',
#  'CARRERA',
#  'LIZA ANGEL',
#  'Fastrack',
# ...

# %%
Product_Description=[]

# %%
#scraping product description from next page
start=1
end=3
for page in range(start,end):
    product_desc=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_desc:
        Product_Description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
Product_Description
# Out:
# ['Others Round Sunglasses (53)',
#  'Polarized Retro Square Sunglasses (53)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (57)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'Others Round Sunglasses (59)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Polarized Rectangular Sunglasses (Free S...',
#  'UV Protection, Mirrored Wayfarer Sunglasses (54)',
#  'UV Protection, Mirrored Wayfarer Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Polarized Round Sunglasses (54)',
#  'UV Protection, Mirrored Wayfarer Sunglasses (57)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Wayfarer Sunglasses (57)',
#  'Others Oval Sunglasses (52)',
# ...

# %%
Price1=[]

# %%
#scraping product description from next page
start=1
end=3
for page in range(start,end):
    price1=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price1:
        Price1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
Price1
# Out:
# ['₹3,999',
#  '₹2,199',
#  '₹499',
#  '₹79',
#  '₹449',
#  '₹79',
#  '₹100',
#  '₹287',
#  '₹79',
#  '₹79',
#  '₹79',
#  '₹2,279',
#  '₹79',
#  '₹79',
#  '₹499',
#  '₹706',
#  '₹74',
#  '₹809',
#  '₹79',
#  '₹799',
#  '₹167',
#  '₹375',
#  '₹459',
#  '₹236',
#  '₹499',
#  '₹479',
#  '₹529',
#  '₹223',
#  '₹214',
#  '₹79',
#  '₹359',
#  '₹499',
#  '₹184',
#  '₹79',
#  '₹244',
#  '₹899',
#  '₹459',
#  '₹461',
#  '₹424',
#  '₹801',
#  '₹1,029',
#  '₹200',
#  '₹809',
#  '₹2,279',
#  '₹200',
#  '₹120',
#  '₹599',
#  '₹2,899',
#  '₹148',
#  '₹499',
#  '₹599',
#  '₹2,909',
#  '₹188',
#  '₹529',
#  '₹79',
#  '₹7,799',
#  '₹79',
#  '₹409',
#  '₹599',
#  '₹6,449',
#  '₹151',
#  '₹809',
#  '₹255',
#  '₹10,929',
#  '₹1,149',
#  '₹146',
#  '₹79',
#  '₹6,889',
#  '₹223',
#  '₹189',
#  '₹1,029',
#  '₹5,139',
#  '₹1,099',
#  '₹271',
#  '₹79',
#  '₹287',
#  '₹424',
#  '₹529',
#  '₹529',
#  '₹5,979']

# %% [markdown]
# Ans:-5

# %%
driver.get('https://www.flipkart.com')

# %%
product=driver.find_element(By.CLASS_NAME,'_3704LK')
product.send_keys('iphone 11')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
clk=driver.find_element(By.XPATH,'//a[@class="_1fQZEK"]')
clk.click()

# %%
Rating=[]

# %%
#Scraping Rating
start=0
end=12
for page in range(start,end):
    rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating:
        Rating.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    nxt.click()
    time.sleep(3)

# %%
Rating
# Out:
# ['5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5']

# %%
Review_sum=[]

# %%
#scraping Review Summary
start=0
end=12
for page in range(start,end):
    rev=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in rev:
        Review_sum.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    nxt.click()
    time.sleep(3)

# %%
Review_sum
# Out:
# ['Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
#  'Perfect product!',
#  'Fabulous!',
#  'Mind-blowing purchase',
#  'Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
#  'Perfect product!',
#  'Fabulous!',
#  'Mind-blowing purchase',
#  'Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
#  'Perfect product!',
#  'Fabulous!',
#  'Mind-blowing purchase',
#  'Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
#  'Perfect product!',
#  'Fabulous!',
#  'Mind-blowing purchase',
#  'Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
#  'Perfect product!',
#  'Fabulous!',
#  'Mind-blowing purchase',
#  'Perfect product!',
#  'Terrific',
#  'Value-for-money',
#  'Classy product',
#  'Good quality product',
# ...

# %%
Full_rev=[]

# %%
#scraping full review
start=0
end=12
for page in range(start,end):
    frev=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in frev:
        Full_rev.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    nxt.click()
    time.sleep(3)

# %%
Full_rev
# Out:
# ["After using 3 years mobile review. Excellent & Awesome Mobile fully I love it mobile don't wait take it perfectly suits everyone very stylish and operating a...\nRead full review",
#  'I am using the phone for last 5 years and found no cons as such. The camera quality is bit low as compared to other iphone varient but it can be managable. B...\nRead full review',
#  "I'm Really happy with the product\nDelivery was fast as well\n..it was a gift for my sister and she loved it so much.",
#  'Awesome for this price range',
#  "impressively Nice......\nOne of the greatest iPhone i ever used ....\nAll was like Never before ...\nit's just Amazing ...\nBattery Life is too good ...2 Days wi...\nRead full review",
#  'Nice products thanks flkat',
#  'Fast performance to previous iPhone x\nGood camera quality but the best part of night mode #killing\n\nI am already One-plus7\nHuge difference between in night m...\nRead full review',
#  'Fantastic and prompt delivery.',
# ...

# %% [markdown]
# Ans:-6

# %%
driver.get('https://www.flipkart.com')

# %%
product=driver.find_element(By.CLASS_NAME,'_3704LK')
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
Brand=[]

# %%
#scraping brand
start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        Brand.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')  
    nxt.click()
    time.sleep(3)

# %%
Brand
# Out:
# ['Wildcraft',
#  'TR',
#  'RED TAPE',
#  'BRUTON',
#  'BRUTON',
#  'World Wear Footwear',
#  'RED TAPE',
#  'Deals4you',
#  'Labbin',
#  'Magnolia',
#  'World Wear Footwear',
#  'BIRDE',
#  'TR',
#  'World Wear Footwear',
#  'BRUTON',
#  'BIRDE',
#  'Kraasa',
#  'PUMA',
#  'Magnolia',
#  'RapidBox',
#  'World Wear Footwear',
#  "K' Footlance",
#  'Shozie',
#  'Layasa',
#  'Rzisbo',
#  'SCATCHITE',
#  'BRUTON',
#  'bacca bucci',
#  'aadi',
#  'tigonis',
#  'Magnolia',
#  "'Trends'",
#  'aadi',
#  'ASTEROID',
#  'Deals4you',
#  'TR',
#  'Robbie jones',
#  'K- FOOTLANCE',
#  'BRUTON',
#  'PUMA',
#  'BRUTON',
#  'WHITE WALKERS',
#  'BRUTON',
#  'Wildcraft',
#  'PUMA',
#  'Sparx',
#  'Elevarse',
#  'TR',
#  'aadi',
#  'Shozie',
#  'BRUTON',
#  'asian',
#  'Deals4you',
#  "Neeman's",
#  'asian',
#  'BIRDE',
#  'RapidBox',
#  'World Wear Footwear',
#  'K- FOOTLANCE',
#  'BIRDE',
#  'Kzaara',
#  'BRUTON',
#  'BRUTON',
#  'Deals4you',
#  'WOODLAND',
#  'HIGHLANDER',
#  'Layasa',
# ...

# %%
Product_Desc=[]

# %%
#scraping product description
start=0
end=3
for page in range(start,end):
    pr=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in pr:
        Product_Desc.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')  
    nxt.click()
    time.sleep(3)

# %%
Product_Desc
# Out:
# ['True Black Shoe Sneakers For Men',
#  'Casual White Sneakers For Men',
#  'Sneakers For Men',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  'Lightweight Pack Of 1 Trendy Sneakers Sneakers For Men',
#  'Latest Collection-1215 Stylish Casual Sports Sneakers F...',
#  'Sneakers For Men',
#  "Newton-01 Men's Lightweight Running Shoes Sneakers For ...",
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Latest Collection Black-349 Trendy & Stylish Casual Sne...',
#  'Sneakers For Men',
#  'Casual Sneakers For Men',
#  'Latest Collection-1216 Stylish Casual Sports Sneakers F...',
#  'Lattest Sneakers Shoe Sneakers For Men',
#  "JUPITER Men's Retro Color Blocked Light Weight Chunky F...",
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'Electron E Pro Sneakers For Men',
#  'Sneakers For Men',
#  'Fashionable casual sneaker shoes Sneakers For Men',
#  'Exclusive Affordable Collection of Trendy & Stylish Cas...',
#  'Fashion and Stylish Soft Ultralight Lace Up Sneakers Ca...',
# ...

# %%
Price=[]

# %%
#scraping price
start=0
end=3
for page in range(start,end):
    price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')  
    nxt.click()
    time.sleep(3)

# %%
Price
# Out:
# ['₹239',
#  '₹409',
#  '₹399',
#  '₹530',
#  '₹4,699',
#  '₹583',
#  '₹233',
#  '₹359',
#  '₹239',
#  '₹287',
#  '₹399',
#  '₹319',
#  '₹344',
#  '₹1,399',
#  '₹473',
#  '₹392',
#  '₹449',
#  '₹143',
#  '₹239',
#  '₹1,320',
#  '₹159',
#  '₹399',
#  '₹393',
#  '₹380',
#  '₹1,298',
#  '₹596',
#  '₹319',
#  '₹236',
#  '₹399',
#  '₹1,275',
#  '₹939',
#  '₹4,899',
#  '₹335',
#  '₹260',
#  '₹236',
#  '₹545',
#  '₹143',
#  '₹999',
#  '₹398',
#  '₹319',
#  '₹1,069',
#  '₹239',
#  '₹899',
#  '₹191',
#  '₹143',
#  '₹143',
#  '₹899',
#  '₹1,320',
#  '₹319',
#  '₹239',
#  '₹179',
#  '₹1,159',
#  '₹239',
#  '₹143',
#  '₹195',
#  '₹2,109',
#  '₹342',
#  '₹1,749',
#  '₹239',
#  '₹1,049',
#  '₹239',
#  '₹239',
#  '₹318',
#  '₹359',
#  '₹329',
#  '₹288',
#  '₹399',
#  '₹739',
#  '₹239',
#  '₹399',
#  '₹239',
#  '₹399',
#  '₹223',
#  '₹399',
#  '₹260',
#  '₹1,414',
#  '₹316',
#  '₹319',
#  '₹206',
#  '₹399',
#  '₹583',
#  '₹239',
#  '₹1,399',
#  '₹530',
#  '₹216',
#  '₹449',
#  '₹239',
#  '₹359',
# ...

# %%
Offer=[]

# %%
#scraping product description
start=0
end=3
for page in range(start,end):
    off=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in off:
        Offer.append(i.text)
    nxt=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')  
    nxt.click()
    time.sleep(3)

# %%
Offer
# Out:
# ['58% off',
#  '84% off',
#  '82% off',
#  '85% off',
#  '76% off',
#  '71% off',
#  '82% off',
#  '62% off',
#  '68% off',
#  '76% off',
#  '64% off',
#  '37% off',
#  '84% off',
#  '71% off',
#  '65% off',
#  '68% off',
#  '84% off',
#  '65% off',
#  '52% off',
#  '64% off',
#  '76% off',
#  '76% off',
#  '68% off',
#  '82% off',
#  '67% off',
#  '69% off',
#  '88% off',
#  '74% off',
#  '73% off',
#  '76% off',
#  '80% off',
#  '47% off',
#  '84% off',
#  '81% off',
#  '73% off',
#  '84% off',
#  '65% off',
#  '84% off',
#  '53% off',
#  '77% off',
#  '35% off',
#  '88% off',
#  '53% off',
#  '75% off',
#  '78% off',
#  '55% off',
#  '76% off',
#  '76% off',
#  '84% off',
#  '84% off',
#  '62% off',
#  '78% off',
#  '77% off',
#  '84% off',
#  '70% off',
#  '60% off',
#  '68% off',
#  '81% off',
#  '81% off',
#  '60% off',
#  '74% off',
#  '72% off',
#  '73% off',
#  '84% off',
#  '64% off',
#  '71% off',
#  '50% off',
#  '61% off',
#  '71% off',
#  '60% off',
#  '72% off',
# ...

# %% [markdown]
# Ans:-7

# %%
driver.get('https://www.myntra.com/shoes')

# %%
#applying color filter
chk=driver.find_element(By.XPATH,'//li[@class="colour-listItem"]')
chk.click()

# %%
#applying price filter
ck=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label')
ck.click()

# %%
Brand=[]

# %%
#scraping Brand
start=0
end=2
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brand:
        Brand.append(i.text)
    nxt=driver.find_element(By.XPATH,'//li[@class="pagination-next"]')   
    nxt.click()
    time.sleep(3)

# %%
Brand
# Out:
# ['Skechers',
#  'Skechers',
#  'Skechers',
#  'ADIDAS',
#  'Puma',
#  'Skechers',
#  'Puma',
#  'Skechers',
#  'Skechers',
#  'Puma',
#  'ADIDAS',
#  'Nike',
#  'ADIDAS Originals',
#  'ADIDAS Originals',
#  'UNDER ARMOUR',
#  'ADIDAS',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'Puma',
#  'Louis Philippe',
#  'UNDER ARMOUR',
#  'Puma',
#  'ADIDAS',
#  'Tommy Hilfiger',
#  'ADIDAS',
#  'Skechers',
#  'UNDER ARMOUR',
#  'Puma',
#  'Puma',
#  'Skechers',
#  'ADIDAS',
#  'ADIDAS',
#  'ADIDAS Originals',
#  'UNDER ARMOUR',
#  'Nike',
#  'Nike',
#  'PUMA Motorsport',
#  'Skechers',
#  'ADIDAS',
#  'Puma',
#  'Puma',
#  'Puma',
#  'ADIDAS',
#  'Skechers',
#  'ADIDAS Originals',
#  'Skechers',
#  'Puma',
#  'Tommy Hilfiger',
#  'ADIDAS Originals',
#  'Skechers',
#  'Skechers',
#  'UNDER ARMOUR',
#  'Reebok',
#  'UNDER ARMOUR',
#  'Calvin Klein',
#  'Skechers',
#  'Puma',
#  'ADIDAS Originals',
#  'Hush Puppies',
#  'Puma',
#  'Puma',
#  'Skechers',
#  'ADIDAS',
#  'Puma',
#  'Hush Puppies',
# ...

# %%
Desc=[]

# %%
#scraping description
start=0
end=2
for page in range(start,end):
    des=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in des:
        Desc.append(i.text)
    nxt=driver.find_element(By.XPATH,'//li[@class="pagination-next"]')   
    nxt.click()
    time.sleep(3)

# %%
Desc
# Out:
# ['Men Velocity Nitro 2 Running',
#  'Men Solid Sneakers',
#  'Men SPORTY RUNNER Sneakers',
#  'Women GO WALK 4 - GIFTED Shoes',
#  'Women Sports Shoes',
#  'Men Leather Formal Brogues',
#  'PEAKFREAK OUTDRY Trekking Shoe',
#  'Women Flex Appeal 3.0 Sneakers',
#  'Men Leather Formal Derbys',
#  'Solid Formal Leather Monk Shoes',
#  'Men Sneakers',
#  'Men Textured Leather Slip-On Sneakers',
#  'Men Leather Sneakers',
#  'Men Leather Derbys',
#  'Men Solid Lightweight Sneakers',
#  'Men ALANINE Running Shoes',
#  'Block Heeled Boots',
#  'Men Running Shoes',
#  'Men MAX ELITE Running Shoes',
#  'SKECH-AIR EDGE BRITE Sneakers',
#  'Leather High-Top Heeled Boots',
#  'Leather Wedge Sandals',
#  "Women D'LUX WALKER Sneakers",
#  'Women Enlighten Shoes',
#  'Embellished Flatform Sandals',
#  'Men Running Shoes',
#  'Men Leather Sneakers',
#  'Women Velocity Nitro 2 Running',
#  'Men Sports Shoes',
#  'Men Leather Sneakers',
#  'Women Electrify Nitro Running',
#  'Men Suede Sneakers',
# ...

# %%
Price=[]

# %%
#scraping Price
start=0
end=2
for page in range(start,end):
    price=driver.find_elements(By.XPATH,'//span[@class="product-discountedPrice"]')
    for i in price:
        Price.append(i.text)
    nxt=driver.find_element(By.XPATH,'//li[@class="pagination-next"]')   
    nxt.click()
    time.sleep(3)

# %%
Price
# Out:
# ['Rs. 8399',
#  'Rs. 6019',
#  'Rs. 11199',
#  'Rs. 8799',
#  'Rs. 5999',
#  'Rs. 11192',
#  'Rs. 8010',
#  'Rs. 6300',
#  'Rs. 6750',
#  'Rs. 8999',
#  'Rs. 8075',
#  'Rs. 8320',
#  'Rs. 7439',
#  'Rs. 6750',
#  'Rs. 8100',
#  'Rs. 10199',
#  'Rs. 8550',
#  'Rs. 8550',
#  'Rs. 7650',
#  'Rs. 6999',
#  'Rs. 9099',
#  'Rs. 6599',
#  'Rs. 8550',
#  'Rs. 8550',
#  'Rs. 9450',
#  'Rs. 11250',
#  'Rs. 6860',
#  'Rs. 6860',
#  'Rs. 7499',
#  'Rs. 7499']

# %% [markdown]
# Ans:-8

# %%
driver.get('https://www.amazon.in')

# %%
product=driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
product.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')
search.click()

# %%
#applying cpu filter
chk=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[11]/span/a/div/label/i')
chk.click()

# %%
#scraping title
Title=[]
title=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')

for i in title[0:10]:
    Title.append(i.text)
    
Title
# Out:
# ['ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS',
#  'Hp Pavilion X360 11Th Gen Intel Core I7 14 Inches Fhd Multitouch 2In1 Laptop (16Gb Ram/512Gb Ssd/B&O/Windows 11 Home/Fpr/Backlit Kb/Intel Iris Xe Graphics/Pen/Alexa/Ms Office/Silver/1.52Kg)14-Dy1047Tu',
#  'ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS',
#  'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN',
# ...

# %%
#scraping Rating
Rating=[]
rating=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')

for i in rating[0:10]:
    Rating.append(i.text)
    
Rating
# Out:
# ['58', '26', '7', '12', '4', '58', '62', '39', '26', '89']

# %%
#scraping Price
Price=[]
price=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')

for i in price[0:10]:
    Price.append(i.text)
    
Price
# Out:
# ['42,999',
#  '80,000',
#  '74,990',
#  '80,000',
#  '64,990',
#  '77,990',
#  '80,990',
#  '1,12,950',
#  '1,00,000',
#  '98,290']
